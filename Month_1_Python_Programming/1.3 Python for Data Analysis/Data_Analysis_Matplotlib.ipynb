# %% [markdown]
# # Python for Data Analysis: Matplotlib Library
# ### Outline of Discussion
#     1. Introduction to Matplotlib
#     2. Creating a Crossplot
#     3. Changing the default color
#     4. Line style and color
#     5. Labels and legends
#     6. Saving a figure
#     7. Subplots
#     8. Creating text inside a plot
#     9. Scatterplots

# %% [markdown]
# # Introduction to Matplotlib
# Matplotlib is a Python 2D plotting module which produces publication quality figures in a variety of formats (jpg, png, etc). In this tutorial, you will learn the basics of how to use the Matplotlib module.
#
# Let's import Matplotlib library. When running Python using the command line, the graphs are typically shown in a separate window. In a Jupyter Notebook, you can simply output the graphs within the notebook itself by running the **%matplotlib inline** command.
#
# So make sure that by default you always use **%matplotlib inline**.
#
# Source: https://www.featureranking.com/tutorials/python-tutorials/matplotlib/

# %%
# import necesary libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# You can also change the default style of plots. Let's go for our favourite style, ggplot. This is something you set and forget. Of course, if you want to use Matplotlib's default options, you can comment this line out.

# %%
plt.style.use('ggplot')

# %% [markdown]
# # Creating a Crossplot
#
# You provide two arrays: one for the horizontal axis x, and the second for the vertical axis y.

# %%
# getting data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 5, 6, 8, 10])

# %% [markdown]
# You can also directly plot two pre-defined numpy arrays

# %%
# plot the graph

plt.plot(x, y)

# %% [markdown]
# The axes automatically match the extent of the data. We would like to give the graph a bit more room, so let's call the **xlim** and **ylim** functions to change the extent of each axis. Here, you can also specify a value of "None" for the default limit.

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 5, 6, 8, 10])

plt.xlim(0, 8)
plt.ylim(0, 12)
plt.plot(x, y)

# %% [markdown]
# ## Changing the default color
# We change the color to red from the default style color.

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 5, 6, 8, 10])

plt.plot(x, y, color='#9FE2BF')

# %% [markdown]
# That's a bit dry, so let's add a title, and x and y labels, and also draw a grid.
#
# In this particular case, since we are using the ggplot style, we get the grid for free, but in the default case, you can use the grid function for displaying a grid.

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 5, 6, 8, 10])

plt.plot(x, y, color='blue')
plt.ylabel('Y-axis')
plt.xlabel('X-axis')
plt.title('Random Y against X')
# Out:
# Text(0.5, 1.0, 'Random Y against X')

# %% [markdown]
# ## Line style and color
# By default, matplotlib draws a line between consecutive points. You can pass a 3rd argument to change the line's style and color. For example "b--" means "blue dashed line".

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 5, 6, 8, 10])

plt.plot(x, y, 'b--')
plt.ylabel('Y-axis')
plt.xlabel('X-axis')
plt.title('Random Y against X')
# Out:
# Text(0.5, 1.0, 'Random Y against X')

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 5, 6, 8, 10])

plt.plot(x, y, 'bo')
plt.ylabel('Y-axis')
plt.xlabel('X-axis')
plt.title('Random Y against X')
# Out:
# Text(0.5, 1.0, 'Random Y against X')

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 5, 6, 8, 10])

plt.plot(x, y, 'k^')
plt.ylabel('Y-axis')
plt.xlabel('X-axis')
plt.title('Random Y against X')
plt.grid(True)

# %% [markdown]
# You can easily plot multiple lines on one graph. You simply call 'plot' multiple times before calling show.
#
# You can also draw simple points instead of lines. Here's an example with green dashes, red dotted line and blue triangles.
#
# Check out the documentation for the full list of style & color options.

# %%
x = np.linspace(-3.0, 3.0, num=60)

# %%
x
# Out:
# array([-3.        , -2.89830508, -2.79661017, -2.69491525, -2.59322034,
#        -2.49152542, -2.38983051, -2.28813559, -2.18644068, -2.08474576,
#        -1.98305085, -1.88135593, -1.77966102, -1.6779661 , -1.57627119,
#        -1.47457627, -1.37288136, -1.27118644, -1.16949153, -1.06779661,
#        -0.96610169, -0.86440678, -0.76271186, -0.66101695, -0.55932203,
#        -0.45762712, -0.3559322 , -0.25423729, -0.15254237, -0.05084746,
#         0.05084746,  0.15254237,  0.25423729,  0.3559322 ,  0.45762712,
#         0.55932203,  0.66101695,  0.76271186,  0.86440678,  0.96610169,
#         1.06779661,  1.16949153,  1.27118644,  1.37288136,  1.47457627,
#         1.57627119,  1.6779661 ,  1.77966102,  1.88135593,  1.98305085,
#         2.08474576,  2.18644068,  2.28813559,  2.38983051,  2.49152542,
#         2.59322034,  2.69491525,  2.79661017,  2.89830508,  3.        ])

# %%
plt.figure(figsize=(15, 8))

plt.plot(x, x, 'b-')
plt.plot(x, x**2, 'r--')
plt.plot(x, x**3, 'k^')
plt.title('Linear, Quadratic and Cubic Functions', fontsize=15)
plt.ylabel('y = x, $x^2$, $x^3$', fontsize=15)
plt.xlabel('x', fontsize=15)
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# ## Labels and legends
# The simplest way to add a legend is to set a label on all lines, then just call the legend function.

# %%
plt.figure(figsize=(15, 8))

plt.plot(x, x, 'b-', label='linear function')
plt.plot(x, x**2, 'r--', label='Quadratic function')
plt.plot(x, x**3, 'k^', label='Cubic function')
plt.legend(loc='upper left')
plt.title('Linear, Quadratic and Cubic Functions', fontsize=15)
plt.ylabel('y = x, $x^2$, $x^3$', fontsize=15)
plt.xlabel('x', fontsize=15)
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# For each plot line, you can set extra attributes, such as the line width, the dash style, or the alpha level. See the full list of attributes in the documentation. You can also overwrite the current style's grid options using the grid function.

# %% [markdown]
# ### Saving a figure
# Saving a figure to disk is as simple as calling savefig with the name of the file (or a file object). The available image formats depend on the graphics backend you use.

# %%
plt.savefig('Linear_Quadratic_Cubic_plot.jpg')

# %% [markdown]
# ## Subplots
# A Matplotlib figure may contain multiple subplots. These subplots are organized in a grid. To create a subplot, just call the subplot function, specify the number of rows and columns in the figure, and the index of the subplot you want to draw on (starting from 1, then left to right, and top to bottom).

# %%
plt.figure(figsize=(10, 10))
x = np.linspace(-3, 3, num=60)

plt.subplot(3, 2, 1)
plt.plot(x, x)
plt.ylabel('y = f(x)', fontsize=15)
plt.xlabel('x')

plt.subplot(3, 2, 2)
plt.plot(x, x**2)
plt.ylabel('$y = f(x)^2$', fontsize=15)
plt.xlabel('x')

plt.subplot(3, 2, 3)
plt.plot(x, x**3)
plt.ylabel('$y = f(x)^3$', fontsize=15)
plt.xlabel('x')

plt.subplot(3, 2, 4)
plt.plot(x, x**4)
plt.ylabel('$y = f(x)^4$', fontsize=15)
plt.xlabel('x')

plt.subplot(3, 2, 5)
plt.plot(x, x**5)
plt.ylabel('$y = f(x)^5$', fontsize=15)
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %%
plt.figure(figsize=(10, 10))
x = np.linspace(-3, 3, num=60)

plt.subplot(2, 3, 1)
plt.plot(x, x)
plt.ylabel('y = f(x)', fontsize=8)
plt.xlabel('x')

plt.subplot(2, 3, 2)
plt.plot(x, x**2)
plt.ylabel('$y = f(x)^2$', fontsize=8)
plt.xlabel('x')

plt.subplot(2, 3, 3)
plt.plot(x, x**3)
plt.ylabel('$y = f(x)^3$', fontsize=8)
plt.xlabel('x')

plt.subplot(2, 3, 4)
plt.plot(x, x**4)
plt.ylabel('$y = f(x)^4$', fontsize=8)
plt.xlabel('x')

plt.subplot(2, 3, 5)
plt.plot(x, x**5)
plt.ylabel('$y = f(x)^5$', fontsize=8)
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# ## Creating text inside a plot
# You can call text to add text at any location in the graph. Just specify the horizontal and vertical coordinates and the text, and optionally some extra attributes.

# %%
x = np.linspace(-1.5, 1.5, num=50)

# %%
px = 0.7
py = px**2

plt.figure(figsize=(10, 8))
plt.plot(x, x**2, 'b-', px, py, 'ro')

plt.text(0, 1.0, 'Quadratic Function\n$y = f(x)^2$', fontsize=15, color='blue', horizontalalignment='center')
# Out:
# Text(0, 1.0, 'Quadratic Function\n$y = f(x)^2$')

# %% [markdown]
# quadratic equation: $y = f(x^2)$

# %% [markdown]
# ## Scatterplots
# To draw a scatterplot, simply provide the x and y coordinates of the points and call the scatter function.

# %%
x = np.random.rand(1, 20)
y = np.random.rand(1, 20)

# %%
x
# Out:
# array([[0.55820131, 0.51702663, 0.53195558, 0.23153622, 0.03771556,
#         0.65516443, 0.1971686 , 0.98348957, 0.18447887, 0.1703403 ,
#         0.10387433, 0.53041308, 0.4200496 , 0.23387878, 0.98668205,
#         0.35228726, 0.08435066, 0.53605876, 0.65695547, 0.86392674]])

# %%
y
# Out:
# array([[0.38603341, 0.60031383, 0.30522255, 0.25258267, 0.52669115,
#         0.60280515, 0.18250475, 0.42467366, 0.28803168, 0.97674437,
#         0.86291748, 0.70360348, 0.75787134, 0.08840786, 0.34554721,
#         0.82454094, 0.39031865, 0.36273339, 0.60617349, 0.577001  ]])

# %%
plt.scatter(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter plot with random data')
# Out:
# Text(0.5, 1.0, 'Scatter plot with random data')

# %%
import matplotlib.pyplot as plt


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x, labels)
ax.legend()

#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(19680801)


def gradient_image(ax, extent, direction=0.3, cmap_range=(0, 1), **kwargs):
    """
    Draw a gradient image based on a colormap.

    Parameters
    ----------
    ax : Axes
        The axes to draw on.
    extent
        The extent of the image as (xmin, xmax, ymin, ymax).
        By default, this is in Axes coordinates but may be
        changed using the *transform* keyword argument.
    direction : float
        The direction of the gradient. This is a number in
        range 0 (=vertical) to 1 (=horizontal).
    cmap_range : float, float
        The fraction (cmin, cmax) of the colormap that should be
        used for the gradient, where the complete colormap is (0, 1).
    **kwargs
        Other parameters are passed on to `.Axes.imshow()`.
        In particular useful is *cmap*.
    """
    phi = direction * np.pi / 2
    v = np.array([np.cos(phi), np.sin(phi)])
    X = np.array([[v @ [1, 0], v @ [1, 1]],
                  [v @ [0, 0], v @ [0, 1]]])
    a, b = cmap_range
    X = a + (b - a) / X.max() * X
    im = ax.imshow(X, extent=extent, interpolation='bicubic',
                   vmin=0, vmax=1, **kwargs)
    return im


def gradient_bar(ax, x, y, width=0.5, bottom=0):
    for left, top in zip(x, y):
        right = left + width
        gradient_image(ax, extent=(left, right, bottom, top),
                       cmap=plt.cm.Blues_r, cmap_range=(0, 0.8))


xmin, xmax = xlim = 0, 10
ymin, ymax = ylim = 0, 1

fig, ax = plt.subplots()
ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)

# background image
gradient_image(ax, direction=1, extent=(0, 1, 0, 1), transform=ax.transAxes,
               cmap=plt.cm.RdYlGn, cmap_range=(0.2, 0.8), alpha=0.5)

N = 10
x = np.arange(N) + 0.15
y = np.random.rand(N)
gradient_bar(ax, x, y, width=0.7)
ax.set_aspect('auto')
plt.show()

# %% [markdown]
# matplotlib: https://matplotlib.org/stable/index.html

# %% [markdown]
# ## Assignment
# Explore and study the seaborne library using the documentation lessons here https://seaborn.pydata.org/tutorial.html.
# Try  to make the above plots now using the seaborne library

# %% [markdown]
# # Conclusion & QA
